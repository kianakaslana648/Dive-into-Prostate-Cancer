# %%
import numpy as np
import random as rd
import pandas as pd
import matplotlib.pyplot as plt

# %%
pX = pd.read_csv('prostate/prostate.csv')
pY = pX.iloc[:,-1]
pX = np.array(pX.iloc[:,1:6034])

# %%
selected = rd.sample(range(6033),300)

# %%
cor = pd.DataFrame(pX[:,selected]).corr()

# %%
heatmap = plt.pcolor(cor)
plt.colorbar(heatmap,cmap='red')
# Out:
# D:\Anaconda\envs\learn\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
